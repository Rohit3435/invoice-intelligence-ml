# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohit3435/invoice-intelligence-ml/blob/main/invoice_intelligence_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3

conn = sqlite3.connect("inventory.db")

# %%
cursor = conn.cursor()

cursor.execute("""
SELECT name
FROM sqlite_master
WHERE type='table';
""")

cursor.fetchall()
# Out:
# []

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.path.exists('/content/drive/MyDrive/Colab Notebooks/inventory.db')
# Out:
# True

# %%
import sqlite3

db_path = '/content/drive/MyDrive/Colab Notebooks/inventory.db'

conn = sqlite3.connect(db_path)

# %%
cursor = conn.cursor()

cursor.execute("""
SELECT name
FROM sqlite_master
WHERE type='table';
""")

cursor.fetchall()
# Out:
# [('purchases',),
#  ('purchase_prices',),
#  ('vendor_invoice',),
#  ('begin_inventory',),
#  ('end_inventory',)]
