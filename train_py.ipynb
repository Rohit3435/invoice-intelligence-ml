# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohit3435/invoice-intelligence-ml/blob/main/train_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile train.py

import joblib
from pathlib import Path

from data_preprocessing import (
    load_vendor_invoice_data,
    prepare_features,
    split_data
)

from modeling_evaluation import (
    train_linear_regression,
    train_decision_tree,
    train_random_forest,
    evaluate_model
)


def main():

    db_path = "data/inventory.db"

    model_dir = Path("models")
    model_dir.mkdir(exist_ok=True)

    # Load data
    df = load_vendor_invoice_data(db_path)

    # Prepare features and target
    X, y = prepare_features(df)

    # Split data
    X_train, X_test, y_train, y_test = split_data(X, y)

    # Train models
    lr_model = train_linear_regression(X_train, y_train)

    dt_model = train_decision_tree(X_train, y_train)

    rf_model = train_random_forest(X_train, y_train)

    # Evaluate models
    results = []

    results.append(
        evaluate_model(
            lr_model,
            X_test,
            y_test,
            "Linear Regression"
        )
    )

    results.append(
        evaluate_model(
            dt_model,
            X_test,
            y_test,
            "Decision Tree Regression"
        )
    )

    results.append(
        evaluate_model(
            rf_model,
            X_test,
            y_test,
            "Random Forest Regression"
        )
    )

    # Select best model using lowest MAE
    best_model_info = min(
        results,
        key=lambda x: x["mae"]
    )

    best_model_name = best_model_info["model_name"]

    models = {
        "Linear Regression": lr_model,
        "Decision Tree Regression": dt_model,
        "Random Forest Regression": rf_model
    }

    best_model = models[best_model_name]

    # Save best model
    model_path = model_dir / "predict_freight_model.pkl"

    joblib.dump(best_model, model_path)

    print(f"\nBest model: {best_model_name}")
    print(f"Model saved at: {model_path}")


if __name__ == "__main__":
    main()
# Out:
# Writing train.py

# %%
import os

os.makedirs("data", exist_ok=True)
os.makedirs("models", exist_ok=True)

# %%
import shutil
import os

os.makedirs("data", exist_ok=True)
os.makedirs("models", exist_ok=True)

shutil.copy(
    "/content/inventory.db",
    "data/inventory.db"
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_496/3950980809.py in <cell line: 0>()
#       5 os.makedirs("models", exist_ok=True)
#       6
# ----> 7 shutil.copy(
#       8     "/content/inventory.db",
#       9     "data/inventory.db"
#
# /usr/lib/python3.13/shutil.py in copy(src, dst, follow_symlinks)
#     426     if os.path.isdir(dst):
#     427         dst = os.path.join(dst, os.path.basename(src))
# --> 428     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     429     copymode(src, dst, follow_symlinks=follow_symlinks)
#     430     return dst
#
# /usr/lib/python3.13/shutil.py in copyfile(src, dst, follow_symlinks)
#     258         os.symlink(os.readlink(src), dst)
#     259     else:
# --> 260         with open(src, 'rb') as fsrc:
#     261             try:
#     262                 with open(dst, 'wb') as fdst:
#
# ...

# %%
# !find /content -name "inventory.db" 2>/dev/null

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !find /content/drive/MyDrive -name "inventory.db" 2>/dev/null
# Out:
# /content/drive/MyDrive/Colab Notebooks/inventory.db

# %%
import shutil
import os

os.makedirs("data", exist_ok=True)
os.makedirs("models", exist_ok=True)

shutil.copy(
    "/content/drive/MyDrive/Colab Notebooks/inventory.db",
    "data/inventory.db"
)
# Out:
# 'data/inventory.db'

# %%
# !ls -lh data
# Out:
# total 405M
# -rw------- 1 root root 405M Aug 30 08:26 inventory.db

# %%
db_path = "data/inventory.db"

# %%
# !ls -lh data
# Out:
# total 405M
# -rw------- 1 root root 405M Aug 30 08:26 inventory.db

# %%
# !ls -lh
# Out:
# total 20K
# drwxr-xr-x 2 root root 4.0K Aug 30 08:26 data
# drwx------ 5 root root 4.0K Aug 30 08:26 drive
# drwxr-xr-x 2 root root 4.0K Aug 30 08:24 models
# drwxr-xr-x 1 root root 4.0K Aug 24 13:21 sample_data
# -rw-r--r-- 1 root root 1.9K Aug 30 08:23 train.py

# %%
# !find /content/drive/MyDrive -name "data_preprocessing.py" -o -name "modeling_evaluation.py"
# Out:
# /content/drive/MyDrive/Colab Notebooks/data_preprocessing.py
# /content/drive/MyDrive/Colab Notebooks/modeling_evaluation.py

# %%
import shutil

shutil.copy(
    "/content/drive/MyDrive/Colab Notebooks/data_preprocessing.py",
    "/content/data_preprocessing.py"
)

shutil.copy(
    "/content/drive/MyDrive/Colab Notebooks/modeling_evaluation.py",
    "/content/modeling_evaluation.py"
)
# Out:
# '/content/modeling_evaluation.py'

# %%
# !ls -lh /content/*.py
# Out:
# -rw------- 1 root root 1.7K Aug 30 08:29 /content/data_preprocessing.py
# -rw------- 1 root root 2.4K Aug 30 08:29 /content/modeling_evaluation.py
# -rw-r--r-- 1 root root 1.9K Aug 30 08:23 /content/train.py
